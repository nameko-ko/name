# %%
#リスト内リストで格納されている座標情報について、x,yを別々のリストに格納する
Contour = [[1,2],[1,3],[3,4],[4,5]]
x = []
y = []
for i in range(len(Contour)):
    x.append(Contour[i][0])
    y.append(Contour[i][1])
print(x)
print(y)
# Out:
# [1, 1, 3, 4]
# [2, 3, 4, 5]

# %%
import numpy as np

x = [1, 1, 3, 4]
y = [2, 3, 4, 5]

r_exp = []
theta_exp = []
#arctan()の返り値を0~2πにして、超えた分はθ+2πとして記録する
first_try = True
second_loop = False
for i in range(len(x)):
    r_exp.append(np.sqrt(x[i] ** 2 + y[i] ** 2))
    theta_check = np.arctan2(y[i],x[i])
    if theta_check > 0 and second_loop == False:
        theta_exp.append(theta_check)
    elif theta_check < 0 and second_loop == False:
        theta_exp.append(2*np.pi+theta_check)
    elif theta_check == 0 and first_try == True:
        theta_exp.append(0)
        first_try = False
    elif theta_check == 0 and first_try == False:
        theta_exp.append(2*np.pi)
        second_loop = True
    if theta_check > 0 and second_loop == True:
        theta_exp.append(theta_check + 2*np.pi)
    elif theta_check < 0 and second_loop == True:
        theta_exp.append(2*np.pi+theta_check + 2*np.pi)


print(r_exp)
print(theta_exp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 29
#      26     elif theta_check < 0 and second_loop == True:
#      27         theta_exp.append(2*np.pi+theta_check + 2*np.pi)
# ---> 29 f
#      31 print(r_exp)
#      32 print(theta_exp)
#
# NameError: name 'f' is not defined

# %%
import matplotlib.pyplot as plt
Contour_all = [[3,0],[2,0.5],[1,1],[0.7,2],[0,3],[-0.3,2],[-1,1],[-2,1],[-3,0],[2,-0.3],[-1,-1],[0.4,-2],[0,-3],[0.6,-2],[1,-1],[2,-0.3],[3,0]]

x, y = zip(*Contour_all)
plt.scatter(x, y)
plt.show()

# %%
#一つの条件のみ表示する
import math
import numpy as np
import matplotlib.pyplot as plt 

a = 1
b = 1
c = 1
d = 0
m = 1

r = []
theta = np.linspace(0, 2*np.pi, 1000)
for i in range(len(theta)):
    r.append(a*(2.0 - b * abs(math.sin(1.5 * c *(theta[i]-d))**m)))

x = r * np.cos(theta)
y = r * np.sin(theta)

fig = plt.figure(figsize = (10,6))
#グラフを描画するsubplot領域を作成。
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
#フォント設定
plt.rcParams["font.family"] = "Arial"
ax1.plot(theta, r)
ax2.plot(x, y)
ax1.set_xlabel('θ')
ax2.set_xlabel('x')
ax1.set_ylabel('r')
ax2.set_ylabel('y')
#テキストボックスの生成
textstr = '\n'.join((
    r'$a=%.2f$' % (a, ),
    r'$b=%.2f$' % (b, ),
    r'$c=%.2f$' % (c, ),
    r'$d=%.2f$' % (d, ),
    r'$m=%.2f$' % (m, )))
# 数式の文字列を生成
equation_str = r'$r=a×(2-b|sin(1.5c(θ - d))|^m)$'
# テキストボックスの属性を設定
props = dict(boxstyle='round', facecolor='white', alpha=0.5)

# テキストボックスを座標 (0.05, 0.95) に配置
ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=10,
        verticalalignment='top', bbox=props)
ax1.text(0.05, 0.95, equation_str, transform=ax1.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)
ax1.set_xlim([0, 6.3])
ax1.set_ylim([0, 4])
ax2.set_xlim([-5, 5])
ax2.set_ylim([-3, 3])

plt.show()

# %%
#一つの条件のみ表示する
import math
import numpy as np
import matplotlib.pyplot as plt 

a = 1 #拡大
b = 1 #遷移1
c = np.pi/3*2 #回転
d = 1 #遷移2
cons = np.pi/3 #定数


r = []
theta = np.linspace(0, 2*np.pi, 1000)
for i in range(len(theta)):
    tmp = (d*theta[i]-c) % (np.pi/1.5)
    #r.append(a*(2.0 - b * abs(math.sin(1.5 * c *(theta[i]-d))**m)))
    r.append(a*(b*(1/math.cos(tmp-cons)-2)+2))

x = r * np.cos(theta)
y = r * np.sin(theta)

fig = plt.figure(figsize = (10,6))
#グラフを描画するsubplot領域を作成。
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
#フォント設定
plt.rcParams["font.family"] = "Arial"
ax1.plot(theta, r)
ax2.plot(x, y)
ax1.set_xlabel('θ')
ax2.set_xlabel('x')
ax1.set_ylabel('r')
ax2.set_ylabel('y')
#テキストボックスの生成
textstr = '\n'.join((
    r'$a=%.2f$' % (a, ),
    r'$b=%.2f$' % (b, ),
    r'$c=%.2f$' % (c, ),
    r'$d=%.2f$' % (d, ),))
# 数式の文字列を生成
equation_str = r'$r=a(b(sec(θ - π/3)-2)+2)$'
# テキストボックスの属性を設定
props = dict(boxstyle='round', facecolor='white', alpha=0.5)

# テキストボックスを座標 (0.05, 0.95) に配置
ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=10,
        verticalalignment='top', bbox=props)
ax1.text(0.05, 0.95, equation_str, transform=ax1.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)
ax1.set_xlim([0, 6.3])
ax1.set_ylim([0, 4])
ax2.set_xlim([-5, 5])
ax2.set_ylim([-3, 3])
#余白の自動調整
plt.tight_layout()

path = "figure_b_{}_d_{}".format(b,d)
plt.savefig("/Users/nametakouhei/name/画像ファイル/{}".format(path),bbox_inches='tight')
plt.show()

# %%
#網羅的に画像の描画をする
import math
import numpy as np
import matplotlib.pyplot as plt 

a = 1 #拡大
b = np.arange(0, 1.25, 0.25) #遷移1
c = 0 #回転
d = np.arange(1/3, 5/3, 1/3) #遷移2
cons = np.pi/3 #定数

theta = np.linspace(0, 2*np.pi, 100)

for j,_ in enumerate(b):
    for i,_ in enumerate(d):
        #break
        r = []
        path = "i_{}_j_{}.jpg".format(i,j)
        for k in range(len(theta)):
            #r.append(2 - i * abs(math.sin(3/2 * j * (theta[k] - c))))
            tmp = (d[i]*theta[k]-c) % (np.pi/1.5)
            r.append(a*(b[j]*(1/math.cos(tmp-cons)-2)+2))

        x = np.array(r) * np.cos(theta)  # xの計算を修正
        y = np.array(r) * np.sin(theta)  # yの計算を修正

        fig = plt.figure(figsize = (10,6))

        #グラフを描画するsubplot領域を作成。
        ax1 = fig.add_subplot(2, 2, 1)
        ax2 = fig.add_subplot(2, 2, 2)
        #テキストボックスの生成
        textstr = '\n'.join((
            r'$a=%.2f$' % (a, ),
            r'$b=%.2f$' % (b[j], ),
            r'$c=%.2f$' % (c, ),
            r'$d=%.2f$' % (d[i], ),))
        # 数式の文字列を生成
        equation_str = r'$r=a(b(sec(θ - π/3)-2)+2)$'
        # テキストボックスの属性を設定
        props = dict(boxstyle='round', facecolor='white', alpha=0.5)
        #グラフの軸の設定
        ax1.plot(theta, r)
        ax2.plot(x, y)
        ax1.set_xlabel('θ')
        ax2.set_xlabel('x')
        ax1.set_ylabel('r')
        ax2.set_ylabel('y')
        ax1.set_xlim([0, 6.3])
        ax1.set_ylim([0, 4])
        ax2.set_xlim([-5, 5])
        ax2.set_ylim([-3, 3])

        ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=10,
        verticalalignment='top', bbox=props)
        ax1.text(0.05, 0.95, equation_str, transform=ax1.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

        plt.savefig("/Users/nametakouhei/name/画像ファイル/{}".format(path))

# %%
import math
import numpy as np
import matplotlib.pyplot as plt 

a = 1  # 拡大
b = np.arange(-0.25, 1.5, 0.25)  # 遷移1
c = 0  # 回転
d = np.arange(0, 2.25, 1/3)  # 遷移2
cons = np.pi/3  # 定数

theta = np.linspace(0, 2*np.pi, 200)

# グラフのサイズ
num_rows = min(len(b), len(d))
num_cols = max(len(b), len(d))

fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 15), sharex=True, sharey=True)

for j, bj in enumerate(b):
    for i, di in enumerate(d):
        if i < num_rows and j < num_cols:  # 現在のインデックスが有効な範囲内か確認
            r = []
            for k in range(len(theta)):
                tmp = (di*theta[k]-c) % (np.pi/1.5)
                r.append(a*(bj*(1/math.cos(tmp-cons)-2)+2))

            x = np.array(r) * np.cos(theta)
            y = np.array(r) * np.sin(theta)

            ax1 = axs[i, j]
            #ax2 = ax1.inset_axes([0.5, 0.5, 0.45, 0.45])

            textstr = '\n'.join((
                r'$b=%.2f$' % (bj, ),
                r'$d=%.2f$' % (di, ),))

            #equation_str = r'$r=a(b(\sec(θ - π/3)-2)+2)$'
            props = dict(boxstyle='round', facecolor='white', alpha=0.5)

            ax1.plot(x, y)
            ax1.set_xlabel('x')
            ax1.set_ylabel('y')
            ax1.set_xlim([-4, 4])
            ax1.set_ylim([-4, 4])

            ax1.text(0.05, 0.95, textstr, transform=ax1.transAxes, fontsize=10,
                     verticalalignment='top', bbox=props)

# レイアウトの調整
fig.tight_layout()
plt.subplots_adjust(wspace=-0.012,hspace=0)

# 保存
plt.savefig("/Users/nametakouhei/name/画像ファイル/output_matrix.png")

# 表示
plt.show()

# %%
#動画読み込み、フレームごと処理、輪郭と重心の計算
import cv2
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from kon import pixel_converter
from kon import assemble_frames_with_order_numbers
from kon import table_image_generator

# ビデオデータの読み込み
filename = "/Users/nametakouhei/name/画像ファイル/四面体.mp4"
base_path= "/Users/nametakouhei/name/画像ファイル/保存データ/"
# 動画ファイルのベース名を取得
video_base_name = os.path.splitext(os.path.basename(filename))[0]

# 動画ごとのディレクトリを作成
video_directory = os.path.join(base_path, video_base_name)
os.makedirs(video_directory, exist_ok=True)  # 既に存在している場合は作成しない
# 新しいフォルダのベース名を指定
folder_names = ["d_image", "d_contours", "d_result", "d_threshold", "d_graph"]

# 新しいフォルダを作成
for folder_name in folder_names:
    new_folder_path = os.path.join(video_directory, folder_name)
    os.makedirs(new_folder_path, exist_ok=True)

# 動画の読み込み
cap = cv2.VideoCapture(filename=filename)
#動画ファイルの情報を取得する
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
hight = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
total_frame = cap.get(cv2.CAP_PROP_FRAME_COUNT)
fps = cap.get(cv2.CAP_PROP_FPS)
print("総フレーム数: ", total_frame)
print("fps: ", fps)
print("動画の長さ: ", total_frame/fps, "[sec]")
# 動画のdpiを取得
video_path = filename
dpi = pixel_converter.get_video_dpi(video_path)
print(dpi)

frame_count = 0  # フレームのカウントを初期化
prev_cx = None  # 前のフレームの重心 x 座標
prev_cy = None  # 前のフレームの重心 y 座標
# グラフ用のデータ格納リスト
area_data = []
perimeter_data = []
moment_data = []
# 重心距離のデータを格納するリスト
centroid_distance_data = []
speed_data = []  # 速度情報を格納するリスト、最初の値を0に初期化
# 重心の座標を格納するリスト
centroid_x_list = []
centroid_y_list = []
centroid_data = []
radius_data = [] # 半径データを格納するためのリスト
# ㎜単位の速度情報を格納するリスト
speed_mm_per_s_data = []
# ㎜単位の重心y座標を格納するリスト
centroid_y_mm_data = []
# ㎜単位の気泡半径を格納するリスト
sphere_radius_mm_data = []
# フレームを格納するリスト
frames = []
# 水平方向と鉛直方向の気泡径のデータを格納するリスト
base_lengths = []
heights = []
base_length_mm_data = []
height_mm_data = []

# 開始フレームを設定
start_frame = 45  
# 開始フレームまで読み込む
for _ in range(start_frame):
    ret, _ = cap.read()
    if not ret:
        print("Error: Failed to read frames.")
        sys.exit(1)

while cap.isOpened() and frame_count < 60:  # 90枚分の処理を行う
    ret, frame = cap.read()
    if ret:
        num = frame_count
        path = os.path.join(video_directory, "d_image/")
        contours_path = os.path.join(video_directory, "d_contours/")
        result_path = os.path.join(video_directory, "d_result/")
        threshold_path = os.path.join(video_directory, "d_threshold/")
        
        image_path = path + "picture{:0=3}.bmp".format(num)
        cv2.imwrite(image_path, frame)

        color_image = cv2.imread(image_path, cv2.IMREAD_COLOR)
        if color_image is None:
            print(f"Error: Failed to load image from {image_path}")
            sys.exit(1)

        gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)
        blurred_image = cv2.bilateralFilter(gray_image, 7, 15, 15 )
        ret, binary = cv2.threshold(blurred_image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        thresholds_path = threshold_path + "threshold_picture{:0=3}.bmp".format(num)
        cv2.imwrite(thresholds_path, binary)

        raw_contours, _ = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
        raw_img_with_contours = frame.copy()
        cv2.drawContours(raw_img_with_contours, raw_contours, -1, (0, 255, 0), 2)
        raw_contours_image_path = os.path.join(contours_path, "raw_contours_picture{:0=3}.bmp".format(num))
        cv2.imwrite(raw_contours_image_path, raw_img_with_contours)

        contours, _ = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
        #print(contours)
        conditions = {
            "min_contour_area": 5000,
            "max_contour_area": 20000,
        }

        filtered_contours = []
        area_data = []
        perimeter_data = []
        moment_data = []

        for idx, contour in enumerate(contours):
            contour_area = cv2.contourArea(contour)

            if (
                ("min_contour_area" not in conditions or contour_area >= conditions["min_contour_area"]) and
                ("max_contour_area" not in conditions or contour_area <= conditions["max_contour_area"])
            ):
                filtered_contours.append(contour)
                area_data.append(contour_area)
                perimeter_data.append(cv2.arcLength(contour, True))
                M = cv2.moments(contour)
                filtered_cx = int(M['m10'] / M['m00']) if M["m00"] != 0 else 0
                filtered_cy = int(M['m01'] / M['m00']) if M["m00"] != 0 else 0
                moment_data.append((filtered_cx, filtered_cy))
# Out:
# 総フレーム数:  1001.0
# fps:  30.00003000003
# 動画の長さ:  33.3666333 [sec]
# 1024
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 111
#     108 raw_contours_image_path = os.path.join(contours_path, "raw_contours_picture{:0=3}.bmp".format(num))
#     109 cv2.imwrite(raw_contours_image_path, raw_img_with_contours)
# --> 111 contours, _ = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
#     112 #print(contours)
#     113 conditions = {
#     114     "min_contour_area": 5000,
#     115     "max_contour_area": 20000,
#     116 }
#
# KeyboardInterrupt:

# %%
import cv2
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import pixel_converter
from assemble_frames_with_order_numbers import assemble_frames_with_order_numbers
from table_image_generator import create_table_image, find_min_max_avg_table

def SearchCF(a, b, c, d, cons, theta_cal, r_obs):
    r_cal = []
    for i in range(len(theta_cal)):
        tmp = (d/3*theta_cal[i]-c) % (np.pi/1.5)
        r_cal.append(a * (b * (1 / np.cos(tmp - cons) - 2) + 2))

    MSE = 0
    for r_obs_i, r_cal_i in zip(r_obs, r_cal):
        MSE += (r_obs_i - r_cal_i) ** 2 / r_cal_i**2

    MSE /= len(r_obs)
    return MSE

def drawCon(a,b,c,d):
    r = []
    theta = np.linspace(0, 2*np.pi, 1000)
    for i in range(len(theta)):
        tmp = (d/3*theta[i]-c) % (np.pi/1.5)
        #r.append(a*(2.0 - b * abs(math.sin(1.5 * c *(theta[i]-d))**m)))
        r.append(a*(b*(1/math.cos(tmp-cons)-2)+2))

    x = r * np.cos(theta)
    y = r * np.sin(theta)

    fig = plt.figure(figsize = (10,6))
    #グラフを描画するsubplot領域を作成。
    ax1 = fig.add_subplot(2, 2, 1)
    #フォント設定
    plt.rcParams["font.family"] = "Arial"
    ax1.plot(x, y)
    ax1.set_xlabel('x')
    ax1.set_ylabel('y')
    #テキストボックスの生成
    textstr = '\n'.join((
        r'$a=%.2f$' % (a, ),
        r'$b=%.2f$' % (b, ),
        r'$c=%.2f$' % (c, ),
        r'$d=%.2f$' % (d, ),
        r'$r=a(b(sec(θ - π/3)-2)+2)$'))
    # テキストボックスの属性を設定
    props = dict(boxstyle='round', facecolor='white', alpha=0.5)

    # テキストボックスを座標 (0.05, 0.95) に配置
    ax1.text(0.05, 0.95, textstr, transform=ax1.transAxes, fontsize=10,
            verticalalignment='top', bbox=props)
    ax1.set_xlim([-80, 80])
    ax1.set_ylim([-50, 50])
    ax1.invert_yaxis()
    #余白の自動調整
    plt.tight_layout()
    plt.show()


# 画像ファイルのパス
image_path = "/Users/nametakouhei/name/画像ファイル/triangle.bmp"

# 画像の読み込み
color_image = cv2.imread(image_path, cv2.IMREAD_COLOR)
if color_image is None:
    print(f"Error: Failed to load image from {image_path}")
    sys.exit(1)

# 画像処理
gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)
blurred_image = cv2.bilateralFilter(gray_image, 7, 15, 15)
denoised_image = cv2.medianBlur(blurred_image, 5)#追加項目
ret, binary = cv2.threshold(denoised_image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# 輪郭の抽出
contours, _ = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

# 輪郭の条件設定
conditions = {
    "min_contour_area": 2000,
    "max_contour_area": 5000,
}

filtered_contours = []
area_data = []
perimeter_data = []
moment_data = []
max_radius = 0

for idx, contour in enumerate(contours):
    contour_area = cv2.contourArea(contour)

    if (
        ("min_contour_area" not in conditions or contour_area >= conditions["min_contour_area"]) and
        ("max_contour_area" not in conditions or contour_area <= conditions["max_contour_area"])
    ):
        filtered_contours.append(contour)
        area_data.append(contour_area)
        perimeter_data.append(cv2.arcLength(contour, True))
        M = cv2.moments(contour)
        filtered_cx = int(M['m10'] / M['m00']) if M["m00"] != 0 else 0
        filtered_cy = int(M['m01'] / M['m00']) if M["m00"] != 0 else 0
        moment_data.append((filtered_cx, filtered_cy))

        # 輪郭上の点と重心の距離を計算し、最大距離を半径とし直径を求める
        for point in contour:
            x, y = point[0]
            distance = math.sqrt((x - filtered_cx)**2 + (y - filtered_cy)**2)
            if distance > max_radius:
                max_radius = distance * 2

# 処理結果の表示（例として最初のフレームのみ）
result_image = color_image.copy()
for contour, moment in zip(filtered_contours, moment_data):
    x_coordinates = [point[0][0] for point in contour]
    y_coordinates = [point[0][1] for point in contour]

    min_x = min(x_coordinates)
    max_x = max(x_coordinates)
    min_y = min(y_coordinates)
    max_y = max(y_coordinates)
    base_length = max_x - min_x
    height = max_y - min_y

    M = cv2.moments(contour)
    rel_con = []
    if M["m00"] != 0:
        filtered_cx, filtered_cy = moment
        area = cv2.contourArea(contour)
        # 重心に点を描画
        cv2.circle(result_image, (filtered_cx, filtered_cy), 5, (0, 0, 255), -1)
        # 輪郭を描画
        cv2.drawContours(result_image, [contour], -1, (0, 255, 0), 2)
        rel_con = contour - moment
    #抽出したcontourの相対座標をx,yリストに分離
    con_x = []
    con_y = []
    for i,con in enumerate(rel_con):
        con_x.append(con[0][0])
        con_y.append(con[0][1]) 
    #r,θの計算
    r_cal = []
    r_obs = []
    theta_cal = []
    theta_obs = []
    for i,_ in enumerate(con_x):
        r_obs.append(np.sqrt(con_x[i]**2 + con_y[i]**2))
        theta_obs.append(np.arctan2(con_y[i],con_x[i]))
    theta_cal = theta_obs
    #最適なa,b,c,dの探索。def SearchCF
    a = np.arange(20,22,0.5)  # 拡大
    b = np.arange(0.7, 1, 0.01)  # 遷移1
    c = np.arange(0, 2.01, 0.01)  # 回転
    d = np.arange(1, 5, 1)  # 遷移2
    cons = np.pi/3  # 定数
    MSE = 100
    ans_a = 0
    ans_b = 0
    ans_c = 0
    ans_d = 0
    for i in a:
        for j in b:
            for k in c:
                for l in d:
                    MSE_tmp = SearchCF(i,j,k,l,cons,theta_cal,r_obs) 
                    if MSE_tmp < MSE:
                        MSE = MSE_tmp
                        ans_a = i
                        ans_b = j
                        ans_c = k
                        ans_d = l
                        #print(str(i)+", "+str(j)+", "+str(k)+", "+str(l)+", "+str(MSE_tmp))
                    
    print("a :" + str(ans_a))
    print("b :" + str(ans_b))
    print("c :" + str(ans_c))
    print("d :" + str(ans_d))
    print(MSE)


# 結果の表示
drawCon(ans_a,ans_b,ans_c,ans_d)
plt.show
plt.imshow(result_image)
plt.title('Processed Image')
plt.savefig("/Users/nametakouhei/name/画像ファイル/Processed Image.png")
plt.show()
# Out:
# a :21.5
# b :0.8
# c :1.48
# d :3
# 0.005124168741859997

# %%
#画像一枚から図形を探索するところ
#simplexを使って素早く探索できるところまではできた
#コード整理ができてない
import cv2
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.optimize import minimize

def SearchCF(params, theta_cal, r_obs):
    a, b, c = params
    d = 3 #設定値
    r_cal = []
    for i in range(len(theta_cal)):
        tmp = (d/3*theta_cal[i]-c) % (np.pi/1.5)
        r_cal.append(a * (b * (1 / np.cos(tmp - np.pi/3) - 2) + 2))

    MSE = 0
    for r_obs_i, r_cal_i in zip(r_obs, r_cal):
        MSE += (r_obs_i - r_cal_i) ** 2 / r_cal_i**2

    MSE /= len(r_obs)
    return MSE

def drawCon(a,b,c):
    r = []
    d = 3
    theta = np.linspace(0, 2*np.pi, 1000)
    for i in range(len(theta)):
        tmp = (d/3*theta[i]-c) % (np.pi/1.5)
        #r.append(a*(2.0 - b * abs(math.sin(1.5 * c *(theta[i]-d))**m)))
        r.append(a*(b*(1/math.cos(tmp-np.pi/3)-2)+2))

    x = r * np.cos(theta)
    y = r * np.sin(theta)

    fig = plt.figure(figsize = (10,6))
    #グラフを描画するsubplot領域を作成。
    ax1 = fig.add_subplot(2, 2, 1)
    #フォント設定
    plt.rcParams["font.family"] = "Arial"
    ax1.plot(x, y)
    ax1.set_xlabel('x')
    ax1.set_ylabel('y')
    #テキストボックスの生成
    textstr = '\n'.join((
        r'$a=%.2f$' % (a, ),
        r'$b=%.2f$' % (b, ),
        r'$c=%.2f$' % (c, ),
        r'$d=%.2f$' % (d, ),
        r'$r=a(b(sec(θ - π/3)-2)+2)$'))
    # テキストボックスの属性を設定
    props = dict(boxstyle='round', facecolor='white', alpha=0.5)

    # テキストボックスを座標 (0.05, 0.95) に配置
    ax1.text(0.05, 0.95, textstr, transform=ax1.transAxes, fontsize=10,
            verticalalignment='top', bbox=props)
    ax1.set_xlim([-80, 80])
    ax1.set_ylim([-50, 50])
    ax1.invert_yaxis()
    #余白の自動調整
    plt.tight_layout()
    plt.show()

# 画像ファイルのパス
image_path = "/Users/nametakouhei/name/画像ファイル/triangle.bmp"

# 画像の読み込み
color_image = cv2.imread(image_path, cv2.IMREAD_COLOR)
if color_image is None:
    print(f"Error: Failed to load image from {image_path}")
    sys.exit(1)

# 画像処理
gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)
blurred_image = cv2.bilateralFilter(gray_image, 7, 15, 15)
denoised_image = cv2.medianBlur(blurred_image, 5)
ret, binary = cv2.threshold(denoised_image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# 輪郭の抽出
contours, _ = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

# 輪郭の条件設定
conditions = {
    "min_contour_area": 2000,
    "max_contour_area": 5000,
}

filtered_contours = []
moment_data = []

for idx, contour in enumerate(contours):
    contour_area = cv2.contourArea(contour)

    if (
        ("min_contour_area" not in conditions or contour_area >= conditions["min_contour_area"]) and
        ("max_contour_area" not in conditions or contour_area <= conditions["max_contour_area"])
    ):
        filtered_contours.append(contour)
        M = cv2.moments(contour)
        filtered_cx = int(M['m10'] / M['m00']) if M["m00"] != 0 else 0
        filtered_cy = int(M['m01'] / M['m00']) if M["m00"] != 0 else 0
        moment_data.append((filtered_cx, filtered_cy))

# 処理結果の表示（例として最初のフレームのみ）
result_image = color_image.copy()
for contour, moment in zip(filtered_contours, moment_data):
    M = cv2.moments(contour)
    rel_con = []
    if M["m00"] != 0:
        filtered_cx, filtered_cy = moment
        # 重心点と輪郭を描画
        cv2.circle(result_image, (filtered_cx, filtered_cy), 5, (0, 0, 255), -1)
        cv2.drawContours(result_image, [contour], -1, (0, 255, 0), 2)
        #輪郭の相対位置を取得
        rel_con = contour - moment
    # 抽出したcontourの相対座標をx, yリストに分離
    con_x = []
    con_y = []
    for i, con in enumerate(rel_con):
        con_x.append(con[0][0])
        con_y.append(con[0][1]) 
    # r, θの計算
    r_obs = []
    theta_obs = []
    for i, _ in enumerate(con_x):
        r_obs.append(np.sqrt(con_x[i]**2 + con_y[i]**2))
        theta_obs.append(np.arctan2(con_y[i], con_x[i]))
    # プロット
    initial_guess = [21, 0.8, 1.5]
    result = minimize(SearchCF, initial_guess, args=(theta_obs, r_obs), method='Nelder-Mead', options={'disp': True})

    # 結果の表示
    print("Optimal parameters:", result.x)
    print("Minimum value:", result.fun)

    # プロット
    drawCon(*result.x[:3])

# 結果の表示
plt.imshow(result_image)
plt.title('Processed Image')
plt.savefig("/Users/nametakouhei/name/画像ファイル/Processed Image.png")
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.005081
#          Iterations: 71
#          Function evaluations: 134
# Optimal parameters: [21.78377932  0.81620336  1.48462341]
# Minimum value: 0.005081320776377667

# %%
#今の所最適なプログラム
import cv2
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

def SearchCF(params, d, theta_cal, r_obs):
    a, b, c = params
    r_cal = []
    for i, _ in enumerate(theta_cal):
        theta_prime = (d / 3 * theta_cal[i] - c) % (np.pi / 1.5)
        r_cal.append(a * (b * (1 / np.cos(theta_prime - np.pi / 3) - 2) + 2))
    
    MSE = np.mean((np.array(r_obs) - np.array(r_cal)) ** 2 / np.array(r_cal) ** 2)
    return MSE

def drawContour(params, d):
    a, b, c = params
    r = []
    theta = np.linspace(0, 2 * np.pi, 1000)
    for i, _ in enumerate(theta):
        theta_prime = (d / 3 * theta[i] - c) % (np.pi / 1.5)
        r.append(a * (b * (1 / np.cos(theta_prime - np.pi / 3) - 2) + 2))
    
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    
    fig = plt.figure(figsize=(10, 6))
    ax = fig.add_subplot(2, 2, 1)
    plt.rcParams["font.family"] = "Arial"
    ax.plot(x, y)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    
    textstr = '\n'.join((
        r'$a=%.2f$' % (a,),
        r'$b=%.2f$' % (b,),
        r'$c=%.2f$' % (c,),
        r'$d=%.2f$' % (d,),
        r'$r=a(b(sec(θ - π/3)-2)+2)$'
    ))
    
    props = dict(boxstyle='round', facecolor='white', alpha=0.5)
    ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=props)
    ax.set_xlim([-80, 80])
    ax.set_ylim([-50, 50])
    ax.invert_yaxis()
    plt.tight_layout()
    plt.show()

# main関数
cap = cv2.VideoCapture('/Users/nametakouhei/name/画像ファイル/四面体.mp4')
d = None
for _ in range(60):
    ret, frame = cap.read()
        
    if not ret or frame is None:
        print("Error: Failed to load image from the video")
        sys.exit(1)
    frame_count += 1
    if frame_count % 2 == 0:
        gray_image = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        blurred_image = cv2.bilateralFilter(gray_image, 7, 15, 15)
        denoised_image = cv2.medianBlur(blurred_image, 5)
        ret, binary = cv2.threshold(denoised_image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        
        contours, _ = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
        conditions = {"min_contour_area": 2000, "max_contour_area": 5000}
        
        filtered_contours = []
        moment_data = []
        
        for _, contour in enumerate(contours):
            contour_area = cv2.contourArea(contour)
            
            if (
                ("min_contour_area" not in conditions or contour_area >= conditions["min_contour_area"]) and
                ("max_contour_area" not in conditions or contour_area <= conditions["max_contour_area"])
            ):
                filtered_contours.append(contour)
                M = cv2.moments(contour)
                filtered_cx = int(M['m10'] / M['m00']) if M["m00"] != 0 else 0
                filtered_cy = int(M['m01'] / M['m00']) if M["m00"] != 0 else 0
                moment_data.append((filtered_cx, filtered_cy))
        
        result_image = frame.copy()

        MSE_standard = float('inf')
        params_result = [0, 0, 0]
        if d == None:
            for contour, moment in zip(filtered_contours, moment_data):
                M = cv2.moments(contour)
                rel_con = []

                if M["m00"] != 0:
                    filtered_cx, filtered_cy = moment
                    cv2.circle(result_image, (filtered_cx, filtered_cy), 5, (0, 0, 255), -1)
                    rel_con = contour - moment

                con_x = []
                con_y = []

                for i, con in enumerate(rel_con):
                    con_x.append(con[0][0])
                    con_y.append(con[0][1])

                r_obs = [np.sqrt(x**2 + y**2) for x, y in zip(con_x, con_y)]
                theta_obs = [np.arctan2(y, x) for x, y in zip(con_x, con_y)]

                for i in range(5):
                    initial_guess = [21, 0.8, 1.5]
                    result = minimize(SearchCF, initial_guess, args=(i, theta_obs, r_obs), method='Nelder-Mead', options={'disp': True})
                    
                    print("Optimal parameters:", result.x)
                    print("Minimum value:", result.fun)

                    if result.fun < MSE_standard:
                        MSE_standard = result.fun
                        params_result = result.x
                        d = i

                drawContour(params_result,d)

        else:
            for contour, moment in zip(filtered_contours, moment_data):
                    M = cv2.moments(contour)
                    rel_con = []

                    if M["m00"] != 0:
                        filtered_cx, filtered_cy = moment
                        cv2.circle(result_image, (filtered_cx, filtered_cy), 5, (0, 0, 255), -1)
                        rel_con = contour - moment

                    con_x = []
                    con_y = []

                    for i, con in enumerate(rel_con):
                        con_x.append(con[0][0])
                        con_y.append(con[0][1])

                    r_obs = [np.sqrt(x**2 + y**2) for x, y in zip(con_x, con_y)]
                    theta_obs = [np.arctan2(y, x) for x, y in zip(con_x, con_y)]

                    initial_guess = [22, 0.7, 1.4]
                    result = minimize(SearchCF, initial_guess, args=(i, theta_obs, r_obs), method='Nelder-Mead', options={'disp': True})
                    
                    print("Optimal parameters:", result.x)
                    print("Minimum value:", result.fun)
            drawContour(result.x,d)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.009929
#          Iterations: 51
#          Function evaluations: 103
# Optimal parameters: [26.22235397  0.57433869  1.67930263]
# Minimum value: 0.009929116133273495
# Optimization terminated successfully.
#          Current function value: 0.007034
#          Iterations: 92
#          Function evaluations: 166
# Optimal parameters: [22.67687039  0.28503132  2.51666023]
# Minimum value: 0.007034288167830663
# Optimization terminated successfully.
#          Current function value: 0.009519
#          Iterations: 95
#          Function evaluations: 168
# Optimal parameters: [18.90846023 -0.21120192  2.3570645 ]
# Minimum value: 0.009519429491358507
# Optimization terminated successfully.
#          Current function value: 0.005915
#          Iterations: 101
#          Function evaluations: 183
# Optimal parameters: [24.76221881  0.47091024  1.37811695]
# Minimum value: 0.00591518441735137
# ...

# %%
#b,dの座標空間のプロット
import cv2
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import pixel_converter
from assemble_frames_with_order_numbers import assemble_frames_with_order_numbers
from table_image_generator import create_table_image, find_min_max_avg_table

def SearchCF(a, b, c, d, cons, theta_cal, r_obs):
    r_cal = []
    for i in range(len(theta_cal)):
        tmp = (d/3*theta_cal[i]-c) % (np.pi/1.5)
        r_cal.append(a * (b * (1 / np.cos(tmp - cons) - 2) + 2))

    MSE = 0
    for r_obs_i, r_cal_i in zip(r_obs, r_cal):
        MSE += (r_obs_i - r_cal_i) ** 2 / r_cal_i**2

    MSE /= len(r_obs)
    return MSE

def drawCon(a,b,c,d):
    r = []
    theta = np.linspace(0, 2*np.pi, 1000)
    for i in range(len(theta)):
        tmp = (d/3*theta[i]-c) % (np.pi/1.5)
        #r.append(a*(2.0 - b * abs(math.sin(1.5 * c *(theta[i]-d))**m)))
        r.append(a*(b*(1/math.cos(tmp-cons)-2)+2))

    x = r * np.cos(theta)
    y = r * np.sin(theta)

    fig = plt.figure(figsize = (10,6))
    #グラフを描画するsubplot領域を作成。
    ax1 = fig.add_subplot(2, 2, 1)
    #フォント設定
    plt.rcParams["font.family"] = "Arial"
    ax1.plot(x, y)
    ax1.set_xlabel('x')
    ax1.set_ylabel('y')
    #テキストボックスの生成
    textstr = '\n'.join((
        r'$a=%.2f$' % (a, ),
        r'$b=%.2f$' % (b, ),
        r'$c=%.2f$' % (c, ),
        r'$d=%.2f$' % (d, ),
        r'$r=a(b(sec(θ - π/3)-2)+2)$'))
    # テキストボックスの属性を設定
    props = dict(boxstyle='round', facecolor='white', alpha=0.5)

    # テキストボックスを座標 (0.05, 0.95) に配置
    ax1.text(0.05, 0.95, textstr, transform=ax1.transAxes, fontsize=10,
            verticalalignment='top', bbox=props)
    ax1.set_xlim([-80, 80])
    ax1.set_ylim([-50, 50])
    ax1.invert_yaxis()
    #余白の自動調整
    plt.tight_layout()
    plt.show()

# 画像ファイルのパス
image_path = "/Users/nametakouhei/name/画像ファイル/triangle.bmp"

# 画像の読み込み
color_image = cv2.imread(image_path, cv2.IMREAD_COLOR)
if color_image is None:
    print(f"Error: Failed to load image from {image_path}")
    sys.exit(1)

# 画像処理
gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)
blurred_image = cv2.bilateralFilter(gray_image, 7, 15, 15)
denoised_image = cv2.medianBlur(blurred_image, 5)#追加項目
ret, binary = cv2.threshold(denoised_image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# 輪郭の抽出
contours, _ = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

# 輪郭の条件設定
conditions = {
    "min_contour_area": 2000,
    "max_contour_area": 5000,
}

filtered_contours = []
area_data = []
perimeter_data = []
moment_data = []
max_radius = 0

for idx, contour in enumerate(contours):
    contour_area = cv2.contourArea(contour)

    if (
        ("min_contour_area" not in conditions or contour_area >= conditions["min_contour_area"]) and
        ("max_contour_area" not in conditions or contour_area <= conditions["max_contour_area"])
    ):
        filtered_contours.append(contour)
        area_data.append(contour_area)
        perimeter_data.append(cv2.arcLength(contour, True))
        M = cv2.moments(contour)
        filtered_cx = int(M['m10'] / M['m00']) if M["m00"] != 0 else 0
        filtered_cy = int(M['m01'] / M['m00']) if M["m00"] != 0 else 0
        moment_data.append((filtered_cx, filtered_cy))

        # 輪郭上の点と重心の距離を計算し、最大距離を半径とし直径を求める
        for point in contour:
            x, y = point[0]
            distance = math.sqrt((x - filtered_cx)**2 + (y - filtered_cy)**2)
            if distance > max_radius:
                max_radius = distance * 2

# 処理結果の表示（例として最初のフレームのみ）
result_image = color_image.copy()
a = 21.5  # 拡大
b = np.arange(0, 1, 0.05)  # 遷移1
c = 1.4  # 回転
d = np.arange(1, 5, 1)  # 遷移2
cons = np.pi/3  # 定数
MSE_list = []
b_value = []
d_value = []

for contour, moment in zip(filtered_contours, moment_data):
    x_coordinates = [point[0][0] for point in contour]
    y_coordinates = [point[0][1] for point in contour]

    min_x = min(x_coordinates)
    max_x = max(x_coordinates)
    min_y = min(y_coordinates)
    max_y = max(y_coordinates)
    base_length = max_x - min_x
    height = max_y - min_y

    M = cv2.moments(contour)
    rel_con = []
    if M["m00"] != 0:
        filtered_cx, filtered_cy = moment
        area = cv2.contourArea(contour)
        # 重心に点を描画
        cv2.circle(result_image, (filtered_cx, filtered_cy), 5, (0, 0, 255), -1)
        # 輪郭を描画
        cv2.drawContours(result_image, [contour], -1, (0, 255, 0), 2)
        rel_con = contour - moment
    #抽出したcontourの相対座標をx,yリストに分離
    con_x = []
    con_y = []
    for i,con in enumerate(rel_con):
        con_x.append(con[0][0])
        con_y.append(con[0][1]) 
    #r,θの計算
    r_cal = []
    r_obs = []
    theta_cal = []
    theta_obs = []
    for i,_ in enumerate(con_x):
        r_obs.append(np.sqrt(con_x[i]**2 + con_y[i]**2))
        theta_obs.append(np.arctan2(con_y[i],con_x[i]))
    theta_cal = theta_obs
    #最適なa,b,c,dの探索。def SearchCF
    for i in range(len(b)):
        for j in range(len(d)):
            MSE_value = SearchCF(a, b[i], c, d[j], cons, theta_cal, r_obs)
            MSE_list.append(MSE_value)
            b_value.append(i)
            d_value.append(j)
            
MSE = np.array(MSE_list)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(b[b_value],d[d_value],MSE)
ax.view_init(elev=5, azim=85)

ax.set_xlim(0,1)
ax.tick_params(axis='both', which='major', labelsize=8)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.set_xticks([0,0.25,0.5,0.75,1.00])
ax.set_yticks([0,1,2,3,4])
ax.set_zticks([0,0.025,0.05,0.075,0.100,0.125,0.150])
ax.set_xlabel('b',fontsize=10)
ax.set_ylabel('d',fontsize=10)
ax.set_zlabel('MSE',fontsize=10)

plt.show()
# Out:
# [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95]
